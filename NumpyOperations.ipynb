# %%
import numpy as np

# %%
new_array = np.random.randint(1,100,20)

# %%
new_array
# Out:
# array([29, 27, 21, 56, 70, 28, 88, 87, 12, 53, 95, 25, 92, 87, 43, 16, 23,
#        63, 93, 48], dtype=int32)

# %%
new_array > 25
# Out:
# array([ True,  True, False,  True,  True,  True,  True,  True, False,
#         True,  True, False,  True,  True,  True, False, False,  True,
#         True,  True])

# %% [markdown]
# #### Koşullu Seçim (Boolean Masking)
#
# Array içindeki elemanları belirli bir koşula göre filtrelemek için kullanılır

# %%
new_array[new_array > 25]
# Out:
# array([29, 27, 56, 70, 28, 88, 87, 53, 95, 92, 87, 43, 63, 93, 48],
#       dtype=int32)

# %% [markdown]
# #### Boyut ve Şekil Değiştirme (Reshape & Transpose)

# %%
# transpose & reshape

# %%
matrix_array = np.array ([[10,20],[20,30],[30,40]])

# %%
matrix_array.shape
# Out:
# (3, 2)

# %%
matrix_array
# Out:
# array([[10, 20],
#        [20, 30],
#        [30, 40]])

# %%
matrix_array.transpose()     # Rowların ve columların yerlerini değiştiriyor.
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
matrix_array.T
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
random_array = np.random.random((6,1))

# %%
random_array
# Out:
# array([[0.04479026],
#        [0.25198338],
#        [0.62525582],
#        [0.58451521],
#        [0.64561928],
#        [0.00501693]])

# %%
random_array.shape
# Out:
# (6, 1)

# %%
random_array.reshape(2,3)
# Out:
# array([[0.04479026, 0.25198338, 0.62525582],
#        [0.58451521, 0.64561928, 0.00501693]])

# %%
random_array.reshape(3,2)
# Out:
# array([[0.04479026, 0.25198338],
#        [0.62525582, 0.58451521],
#        [0.64561928, 0.00501693]])

# %%
veri_listesi = [1, 2, 3, 4, 5]
numpy_dizisi = np.array(veri_listesi)
